# %%
import pandas as pd #data fram
import numpy as np #math
import seaborn as sns #vis
import matplotlib.pyplot as plt #vis
from sklearn.model_selection import train_test_split #split data
from sklearn.linear_model import LinearRegression #models
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error #error evalution

# %%
data = pd.read_csv("/content/drive/MyDrive/Position_Salaries (1).csv")
data.head()

# %%
data.info()

# %%
data.describe()

# %%
plt.figure(figsize=(12,6))
sns.pairplot(data,height=4,kind="scatter")
plt.xlabel("Level")
plt.ylabel("Salary")
plt.title("Salary prediction")
plt.show()

# %%
x = data.iloc[:,1:2]
y = data.iloc[:,1]

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,train_size=0.8, random_state=10)

my_model = LinearRegression()

my_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=my_model.predict(x_train)

# %%
plt.scatter(x_train, y_train, color = 'red')
plt.plot(x_train, y_predict , color = "blue")
plt.title("Salary vs Experince(training set)")
plt.xlabel("Level")
plt.ylabel("Salary")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
